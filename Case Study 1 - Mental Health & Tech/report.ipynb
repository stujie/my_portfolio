# %% [markdown]
# # Case Study #1: Mental Health in Tech

# %% [markdown]
# ## 1.0 Introduction
# In this case study, we will analyze one data set compiled of survey responses. Input variables are a balance of variables that cover participant demographics and employment characteristics.
#
# The 27 survey questions are highlighted by their own input variables, each of which are discussed further in **2.2 Variables.**

# %% [markdown]
# ## 2.0 Data Set
#
# ### 2.1 Source
# This dataset is from a 2014 survey that measures attitudes towards mental health and frequency of mental health disorders in the tech workplace.
#
# I located and downloaded the necessary files for this study from kaggle.com. The organization that originally uploaded this dataset to kaggle is Open Source Mental Illness (OSMI), a non-profit organization dedicated to raising awareness, educating, and providing resources to support mental wellness in the tech and open source communities.
#
# [Link: https://www.kaggle.com/datasets/osmi/mental-health-in-tech-survey](https://www.kaggle.com/datasets/osmi/mental-health-in-tech-survey)
#
# ### 2.2 Variable Descriptions
# | # | Variable | Description|
# | --- | --- | --- |
# | 1 | Timestamp | Date and time at which the survey response was submitted |
# | 2 | Age | Respondent age |
# | 3 | Gender | Respondent gender |
# | 4 | Country | Respondent country of residence |
# | 5 | state | If respondent lives in the United States, shows the abbreivation for their state of residence |
# | 6 | self_employed | Is respondent self-employed? |
# | 7 | family_history | Does respondent have a family history of mental illness? |
# | 8 | treatment | Has respondent sought treatment for a mental health condition? |
# | 9 | work_interfere | If respondent has mental health condition, do they feel that it interferes with their work? |
# | 10 | no_employees | How many employees does the respondent's company/organization have? |
# | 11 | remote_work | Does respondent work remotely (outside of office) at least 50% of the time? |
# | 12 | tech_company | Is respondent's employer primarily a tech company/organization? |
# | 13 | benefits | Does respondent's employer provide mental health benefits? |
# | 14 | care_options | Does respondent know the options for mental health care that their employer provides? |
# | 15 | wellness_program | Has respondent ever discussed mental health as part of an employee wellness program? |
# | 16 | seek_help | Does respondent's employer provide resources to learn more about mental health issues and how to seek help? |
# | 17 | anonymity | Is respondent's anonymity protected if they choose to take advantage of mental health or substance abuse treatment resources? |
# | 18 | leave | How easy is it for respondent to take medical leave for a mental health condition? |
# | 19 | mental_health_consequence | Does respondent think that discussing a mental health issue with their employer would have negative consequences? |
# | 20 | phys_health_consequence | Does respondent think that discussing a physical health issue with their employer would have negative consequences? |
# | 21 | coworkers | Would respondent be willing to discuss a mental health issue with their coworkers? |
# | 22 | supervisor | Would respondent be willing to discuss a mental health issue with their direct supervisor(s)? |
# | 23 | mental_health_interview | Would respondent bring up a mental health issue with a potential employer in an interview? |
# | 24 | phys_health_interview | Would respondent bring up a physical health issue with a potential employer in an interview? |
# | 25 | mental_vs_physical | Does respondent feel that their employer takes mental health as seriously as physical health? |
# | 26 | obs_consequence | Has the respondent ever heard of or observed negative consequences for coworkers with mental health conditions in their workplace? |
# | 27 | comments | Any additional notes or comments. |

# %% [markdown]
# ## 3.0 Objectives
# Based on the data set provided, I would like to analyze whether there is a relation between respondent's having a family history of mental health and their openness to talking about mental health in their tech work places. I would also like to dig into whether there is any distinctions in this relationship based on respondent's country of origin.
# ### 3.1 Inspiration Questions
# The Kaggle uploader and datset collector, OSMI, highlighted the following questions as potential areas of baseline analysis.
# 1. How does the frequency of mental health illness and attitudes towards mental health vary by geographic location?
# 2. What are the strongest predictors of mental health illness or certain attitudes towards mental health in the workplace?
# ### 3.2 Guiding Questions
# Based on the dataset, I have come up with the following questions in order to provide some more specific structure to my analysis.
# 1. Are respondents with a family history of mental illness more or less likely to discuss mental health issues with their coworkers and supervisors?
# 2. Which countries show a gap between employee's awareness of mental health resources and their likelihood of seeking out treatment?

# %% [markdown]
# ## 4.0 Assessing Data

# %% [markdown]
# ### 4.1 Context and Relevance
# The data I used for this case study was sourced by:
#
# a. Where is the data set coming from?
#
# b. How is the data sourced?
#
# c. How is the data collected?
#
# d. How often is the data updated?
#
# e. Are there any potential biases in the data?
#
# Next, let's take a deeper look at our data.

# %% [markdown]
# ### 4.2 Data Quality

# %%
# import libraries and load csv
import pandas as pd
import numpy as np

survey = pd.read_csv(r'survey.csv')

# %%
# check for missing values
survey.isnull().sum()
# Out:
# Timestamp                       0
# Age                             0
# Gender                          0
# Country                         0
# state                         515
# self_employed                  18
# family_history                  0
# treatment                       0
# work_interfere                264
# no_employees                    0
# remote_work                     0
# tech_company                    0
# benefits                        0
# care_options                    0
# wellness_program                0
# seek_help                       0
# anonymity                       0
# leave                           0
# mental_health_consequence       0
# phys_health_consequence         0
# coworkers                       0
# supervisor                      0
# mental_health_interview         0
# phys_health_interview           0
# mental_vs_physical              0
# obs_consequence                 0
# comments                     1095
# dtype: int64

# %%
# check for duplicate rows in survey dataset
survey.duplicated().sum()
# Out:
# np.int64(1)

# %% [markdown]
# ### 4.3 Data Structure and Types

# %%
# number of samples and variables in survey dataset
survey.shape
# Out:
# (1259, 27)

# %%
# check column types & missing values
survey.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  1259 non-null   str
#  1   Age                        1259 non-null   int64
#  2   Gender                     1259 non-null   str
#  3   Country                    1259 non-null   str
#  4   state                      744 non-null    str
#  5   self_employed              1241 non-null   str
#  6   family_history             1259 non-null   str
#  7   treatment                  1259 non-null   str
#  8   work_interfere             995 non-null    str
#  9   no_employees               1259 non-null   str
#  10  remote_work                1259 non-null   str
#  11  tech_company               1259 non-null   str
#  12  benefits                   1259 non-null   str
#  13  care_options               1259 non-null   str
# ...

# %% [markdown]
# ### 4.4 Distribution

# %%
# statistical summary for numerical columns
pd.set_option('display.float_format', '{:.2f}'.format)
survey.describe()
# Out:
#                  Age
# count        1259.00
# mean     79428148.31
# std    2818299442.98
# min         -1726.00
# 25%            27.00
# 50%            31.00
# 75%            36.00
# max   99999999999.00

# %% [markdown]
# ## 5.0 Data Cleaning
#
# ### 5.1 Dedupe

# %%
# drop duplicates
survey = survey.drop_duplicates()
survey
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0      8/27/2014 11:29   37  Female   United States    IL           NaN
# 1      8/27/2014 11:29   44       M   United States    IN           NaN
# 2      8/27/2014 11:29   32    Male          Canada   NaN           NaN
# 3      8/27/2014 11:29   31    Male  United Kingdom   NaN           NaN
# 4      8/27/2014 11:30   31    Male   United States    TX           NaN
# ...                ...  ...     ...             ...   ...           ...
# 1254   9/12/2015 11:17   26    male  United Kingdom   NaN            No
# 1255    9/26/2015 1:07   32    Male   United States    IL            No
# 1256   11/7/2015 12:36   34    male   United States    CA            No
# 1257  11/30/2015 21:25   46       f   United States    NC            No
# 1258    2/1/2016 23:04   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %% [markdown]
# ### 5.2 Remove Extraneous Columns

# %% [markdown]
# ### 5.2 Column Transformations

# %%
# transforming timestamp column
survey[["Date","Time"]] = survey["Timestamp"].str.split(" ", expand=True)
survey = survey.drop(columns = ["Time"])
survey[["Month","Day","Year"]] = survey["Date"].str.split("/",n=2,expand=True)
survey
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0      8/27/2014 11:29   37  Female   United States    IL           NaN
# 1      8/27/2014 11:29   44       M   United States    IN           NaN
# 2      8/27/2014 11:29   32    Male          Canada   NaN           NaN
# 3      8/27/2014 11:29   31    Male  United Kingdom   NaN           NaN
# 4      8/27/2014 11:30   31    Male   United States    TX           NaN
# ...                ...  ...     ...             ...   ...           ...
# 1254   9/12/2015 11:17   26    male  United Kingdom   NaN            No
# 1255    9/26/2015 1:07   32    Male   United States    IL            No
# 1256   11/7/2015 12:36   34    male   United States    CA            No
# 1257  11/30/2015 21:25   46       f   United States    NC            No
# 1258    2/1/2016 23:04   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %%
# transform gender column responses

# %%
# transform no_employees column responses
survey["no_employees"] = survey["no_employees"].str.replace("25-Jun","6-25")
survey["no_employees"] = survey["no_employees"].str.replace("5-Jan", "1-5")
survey["no_employees"] = survey["no_employees"].str.replace("More than 1000", "1000-5000")
survey[["min_employees","max_employees"]] = survey["no_employees"].str.split("-",expand=True)
survey
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0      8/27/2014 11:29   37  Female   United States    IL           NaN
# 1      8/27/2014 11:29   44       M   United States    IN           NaN
# 2      8/27/2014 11:29   32    Male          Canada   NaN           NaN
# 3      8/27/2014 11:29   31    Male  United Kingdom   NaN           NaN
# 4      8/27/2014 11:30   31    Male   United States    TX           NaN
# ...                ...  ...     ...             ...   ...           ...
# 1254   9/12/2015 11:17   26    male  United Kingdom   NaN            No
# 1255    9/26/2015 1:07   32    Male   United States    IL            No
# 1256   11/7/2015 12:36   34    male   United States    CA            No
# 1257  11/30/2015 21:25   46       f   United States    NC            No
# 1258    2/1/2016 23:04   25    Male   United States    IL            No
#
#      family_history treatment work_interfere no_employees  ...  \
# ...

# %% [markdown]
# ### 5.3 Remove Extraneous Columns

# %%
# drop comments and state column
survey = survey.drop(columns = ["comments", "state","Date","Month","Day"])
survey
# Out:
#              Timestamp  Age  Gender         Country self_employed  \
# 0      8/27/2014 11:29   37  Female   United States           NaN
# 1      8/27/2014 11:29   44       M   United States           NaN
# 2      8/27/2014 11:29   32    Male          Canada           NaN
# 3      8/27/2014 11:29   31    Male  United Kingdom           NaN
# 4      8/27/2014 11:30   31    Male   United States           NaN
# ...                ...  ...     ...             ...           ...
# 1254   9/12/2015 11:17   26    male  United Kingdom            No
# 1255    9/26/2015 1:07   32    Male   United States            No
# 1256   11/7/2015 12:36   34    male   United States            No
# 1257  11/30/2015 21:25   46       f   United States            No
# 1258    2/1/2016 23:04   25    Male   United States            No
#
#      family_history treatment work_interfere no_employees remote_work  ...  \
# 0                No       Yes          Often         6-25          No  ...
# ...

# %% [markdown]
# ### 5.4 Handle Invalid Values

# %%
# move date
